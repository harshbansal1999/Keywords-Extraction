# %%
import numpy as np
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import sent_tokenize, word_tokenize
import pandas as pd
# Out:
# [nltk_data] Downloading package punkt to C:\Users\neeraj
# [nltk_data]     bansal\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\neeraj
# [nltk_data]     bansal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import PyPDF2
pdf_file = open('JavaBasics-notes.pdf',"rb")
read_pdf = PyPDF2.PdfFileReader(pdf_file)
number_of_pages = read_pdf.getNumPages()
page = read_pdf.getPage(0)
page_content = page.extractText()
print(page_content)
# Out:
# Java Basics© 1996-2003 jGuru.com. All Rights Reserved.Java Basics -1Java BasicsTopics in this section include:! What makes Java programs portable, secure, and robust! The structure of Java applets and applications! How Java applications are executed! How applets are invoked and executed! The Java Language, Part I! Comments! Declarations! Expressions! Statements! Garbage collection! Java SemanticsPortabilityJava programs are portable across operating systems and hardware environments.Portability is to your advantage because:! You need only one version of your software to serve a broad market.! The Internet, in effect, becomes one giant, dynamic library.! You are no longer limited by your particular computer platform.Three features make Java String programs portable:1. The language. The Java language is completely specified; all data-type sizes andformats are defined as part of the language. By contrast, C/C++ leaves these"details" up to the compiler implementor, and many C/C++ program
# ...

# %%
content={}
for i in range(number_of_pages):
    page1=read_pdf.getPage(i)
    content[i]=page1.extractText()
content
# Out:
# {0: 'Java Basics© 1996-2003 jGuru.com. All Rights Reserved.Java Basics -1Java BasicsTopics in this section include:! What makes Java programs portable, secure, and robust! The structure of Java applets and applications! How Java applications are executed! How applets are invoked and executed! The Java Language, Part I! Comments! Declarations! Expressions! Statements! Garbage collection! Java SemanticsPortabilityJava programs are portable across operating systems and hardware environments.Portability is to your advantage because:! You need only one version of your software to serve a broad market.! The Internet, in effect, becomes one giant, dynamic library.! You are no longer limited by your particular computer platform.Three features make Java String programs portable:1. The language. The Java language is completely specified; all data-type sizes andformats are defined as part of the language. By contrast, C/C++ leaves these"details" up to the compiler implementor, and many C/C++ pr
# ...

# %%
number_of_pages
# Out:
# 23

# %%
content[1]
# Out:
# 'Java BasicsJava Basics -2© 1996-2003 jGuru.com. All Rights Reserved.are not portable.2. The library. The Java class library is available on any machine with a Javaruntime system, because a portable program is of no use if you cannot use thesame class library on every platform. Window-manager function calls in a Macapplication written in C/C++, for example, do not port well to a PC.3. The byte code. The Java runtime system does not compile your source codedirectly into machine language, an inflexible and nonportable representation ofyour program. Instead, Java programs are translated into machine-independentbyte code. The byte code is easily interpreted and therefore can be executed onany platform having a Java runtime system. (The latest versions of the NetscapeNavigator browser, for example, can run applets on virtually any platform).SecurityThe Java language is secure in that it is very difficult to write incorrect code orviruses that can corrupt/steal your data, or harm hardware 
# ...

# %%
dict1={}
for i in range(23):
    word=word_tokenize(content[i])
    dict1[i]=word
dict1
# Out:
# {0: ['Java',
#   'Basics©',
#   '1996-2003',
#   'jGuru.com',
#   '.',
#   'All',
#   'Rights',
#   'Reserved.Java',
#   'Basics',
#   '-1Java',
#   'BasicsTopics',
#   'in',
#   'this',
#   'section',
#   'include',
#   ':',
#   '!',
#   'What',
#   'makes',
#   'Java',
#   'programs',
#   'portable',
#   ',',
#   'secure',
#   ',',
#   'and',
#   'robust',
#   '!',
#   'The',
#   'structure',
#   'of',
#   'Java',
#   'applets',
#   'and',
#   'applications',
#   '!',
#   'How',
#   'Java',
#   'applications',
#   'are',
#   'executed',
#   '!',
#   'How',
#   'applets',
#   'are',
#   'invoked',
#   'and',
#   'executed',
#   '!',
#   'The',
#   'Java',
#   'Language',
#   ',',
#   'Part',
#   'I',
#   '!',
#   'Comments',
#   '!',
#   'Declarations',
#   '!',
#   'Expressions',
#   '!',
#   'Statements',
#   '!',
#   'Garbage',
#   'collection',
#   '!',
#   'Java',
#   'SemanticsPortabilityJava',
#   'programs',
#   'are',
#   'portable',
#   'across',
#   'operating',
# ...

# %%
doc=[]
for i in range(23):
    doc.append(dict1[i])
doc
# Out:
# [['Java',
#   'Basics©',
#   '1996-2003',
#   'jGuru.com',
#   '.',
#   'All',
#   'Rights',
#   'Reserved.Java',
#   'Basics',
#   '-1Java',
#   'BasicsTopics',
#   'in',
#   'this',
#   'section',
#   'include',
#   ':',
#   '!',
#   'What',
#   'makes',
#   'Java',
#   'programs',
#   'portable',
#   ',',
#   'secure',
#   ',',
#   'and',
#   'robust',
#   '!',
#   'The',
#   'structure',
#   'of',
#   'Java',
#   'applets',
#   'and',
#   'applications',
#   '!',
#   'How',
#   'Java',
#   'applications',
#   'are',
#   'executed',
#   '!',
#   'How',
#   'applets',
#   'are',
#   'invoked',
#   'and',
#   'executed',
#   '!',
#   'The',
#   'Java',
#   'Language',
#   ',',
#   'Part',
#   'I',
#   '!',
#   'Comments',
#   '!',
#   'Declarations',
#   '!',
#   'Expressions',
#   '!',
#   'Statements',
#   '!',
#   'Garbage',
#   'collection',
#   '!',
#   'Java',
#   'SemanticsPortabilityJava',
#   'programs',
#   'are',
#   'portable',
#   'across',
#   'operating',
# ...

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
from nltk.corpus import wordnet
def get_simple_pos(tag):
    
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
from nltk import pos_tag
from nltk.corpus import stopwords
import string
stops = set(stopwords.words('english'))
punctuations = list(string.punctuation)
stops.update(punctuations)

# %%
def clean_review(words):
    output_words = []
    for w in words:
        if w.lower() not in stops:
            pos = pos_tag([w])
            clean_word = lemmatizer.lemmatize(w, pos = get_simple_pos(pos[0][1]))
            output_words.append(clean_word.lower())
    return output_words

# %%
documents = [(clean_review(document)) for document in doc]

# %%
documents[1][0].isalpha()
# Out:
# True

# %%
documents
# Out:
# [['java',
#   'basics©',
#   '1996-2003',
#   'jguru.com',
#   'rights',
#   'reserved.java',
#   'basics',
#   '-1java',
#   'basicstopics',
#   'section',
#   'include',
#   'make',
#   'java',
#   'program',
#   'portable',
#   'secure',
#   'robust',
#   'structure',
#   'java',
#   'applet',
#   'application',
#   'java',
#   'application',
#   'execute',
#   'applet',
#   'invoked',
#   'execute',
#   'java',
#   'language',
#   'part',
#   'comments',
#   'declarations',
#   'expressions',
#   'statements',
#   'garbage',
#   'collection',
#   'java',
#   'semanticsportabilityjava',
#   'program',
#   'portable',
#   'across',
#   'operating',
#   'system',
#   'hardware',
#   'environments.portability',
#   'advantage',
#   'need',
#   'one',
#   'version',
#   'software',
#   'serve',
#   'broad',
#   'market.',
#   'internet',
#   'effect',
#   'becomes',
#   'one',
#   'giant',
#   'dynamic',
#   'library.',
#   'longer',
#   'limited',
#   'particular',
#   'computer',
# ...

# %%
doc2=[]
for q in range(23):
    for j in range(len(documents[q])):
        if(documents[q][j].isalpha() and len(documents[q][j])>2):
            doc2.append(documents[q][j])
len(doc2)
# Out:
# 1897

# %%
doc2.sort(key=len)
doc2
# Out:
# ['one',
#  'one',
#  'use',
#  'use',
#  'run',
#  'two',
#  'bad',
#  'bad',
#  'set',
#  'two',
#  'www',
#  'use',
#  'www',
#  'may',
#  'one',
#  'run',
#  'www',
#  'add',
#  'gui',
#  'use',
#  'use',
#  'bar',
#  'awt',
#  'gui',
#  'etc',
#  'etc',
#  'use',
#  'one',
#  'web',
#  'web',
#  'may',
#  'use',
#  'www',
#  'tag',
#  'img',
#  'tag',
#  'tag',
#  'alt',
#  'tag',
#  'end',
#  'two',
#  'use',
#  'try',
#  'use',
#  'may',
#  'use',
#  'int',
#  'bit',
#  'bit',
#  'bit',
#  'int',
#  'may',
#  'use',
#  'new',
#  'foo',
#  'new',
#  'int',
#  'new',
#  'new',
#  'new',
#  'new',
#  'new',
#  'int',
#  'may',
#  'may',
#  'may',
#  'use',
#  'one',
#  'two',
#  'may',
#  'use',
#  'may',
#  'abc',
#  'int',
#  'use',
#  'int',
#  'use',
#  'int',
#  'may',
#  'use',
#  'new',
#  'int',
#  'new',
#  'int',
#  'int',
#  'new',
#  'int',
#  'new',
#  'new',
#  'use',
#  'new',
#  'new',
#  'new',
#  'new',
#  'new',
#  'two',
#  'new',
#  'new',
#  'one',
#  'new',
# ...

# %%
np.savetxt("keywords_.csv",doc2,fmt="%s")
